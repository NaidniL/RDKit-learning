# %% [markdown]
# # 疑似无机含碳结构：44 个唯一结构可视化
#
# 数据来自审计批次 `20260704_100408_933902_UTC_07d4f39d`。共 11 个代码单元，每个单元单排绘制 4 个分子。图例中 `INCLUDE`、`EXCLUDE` 和 `REVIEW` 仅表示预审建议，不是正式人工决策。

# %%
from rdkit import Chem
from rdkit.Chem import Draw

def draw_review_batch(items):
    mols = []
    legends = []
    for number, recommendation, inchikey, smiles, name in items:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            raise ValueError(f'No. {number} SMILES cannot be parsed: {smiles}')
        mols.append(mol)
        legends.append(f'{number}. {name}\n{recommendation} | {inchikey[:14]}')
    return Draw.MolsToGridImage(
        mols, molsPerRow=4, subImgSize=(320, 260), legends=legends, useSVG=False
    )

batch = [
    (1, 'EXCLUDE', 'ATDGTVJJHBUTRL-UHFFFAOYSA-N', 'N#CBr', 'Cyanogen bromide'),
    (2, 'REVIEW', 'BABMCXWQNSQAOC-UHFFFAOYSA-M', 'C[Hg]Cl', 'Methylmercury chloride'),
    (3, 'INCLUDE', 'BAVYZALUXZFZLV-UHFFFAOYSA-N', 'CN', 'Methylamine / methylamine hydrochloride'),
    (4, 'INCLUDE', 'BDAGIHXWWSANSR-UHFFFAOYSA-N', 'O=CO', 'Formic acid / sodium formate'),
]
draw_review_batch(batch)

# %%
batch = [
    (5, 'REVIEW', 'CIJBKNZDKBKMFU-FIBGUPNXSA-N', '[2H]C([2H])([2H])NN=O', 'Potassium (Z)-ethanediazotate'),
    (6, 'REVIEW', 'CIJBKNZDKBKMFU-SUEIGJEOSA-N', 'C[15NH][15N]=O', 'Potassium (E)-ethanediazotate'),
    (7, 'EXCLUDE', 'CRDYSYOERSZTHZ-UHFFFAOYSA-N', 'N#C[SeH]', 'Potassium selenocyanate'),
    (8, 'REVIEW', 'DBUXSCUEGJMZAE-UHFFFAOYSA-N', 'C[Hg+]', 'Methylmercury hydroxide / methylmercury'),
]
draw_review_batch(batch)

# %%
batch = [
    (9, 'INCLUDE', 'DIKBFYAXUHHXCS-UHFFFAOYSA-N', 'BrC(Br)Br', 'Bromoform / tribromomethane'),
    (10, 'REVIEW', 'DKVNPHBNOWQYFE-UHFFFAOYSA-N', 'NC(=S)S', 'Sodium diethyldithiocarbamate'),
    (11, 'INCLUDE', 'FJBFPHVGVWTDIP-UHFFFAOYSA-N', 'BrCBr', 'Dibromomethane'),
    (12, 'INCLUDE', 'FMWLUWPQPKEARP-UHFFFAOYSA-N', 'ClC(Cl)Br', 'Bromodichloromethane'),
]
draw_review_batch(batch)

# %%
batch = [
    (13, 'INCLUDE', 'GATVIKZLVQHOMN-UHFFFAOYSA-N', 'ClC(Br)Br', 'Chlorodibromomethane'),
    (14, 'INCLUDE', 'GZUXJHMPEANEGY-UHFFFAOYSA-N', 'CBr', 'Methyl bromide / bromomethane'),
    (15, 'EXCLUDE', 'HBMJWWWQQXIZIP-UHFFFAOYSA-N', '[C-]#[SiH2+]', 'Silicon carbide'),
    (16, 'INCLUDE', 'HDZGCSFEDULWCS-UHFFFAOYSA-N', 'CNN', 'Methylhydrazine / methylhydrazine sulfate'),
]
draw_review_batch(batch)

# %%
batch = [
    (17, 'INCLUDE', 'HEDRZPFGACZZDS-UHFFFAOYSA-N', 'ClC(Cl)Cl', 'Chloroform'),
    (18, 'INCLUDE', 'INQOMBQAUSQDDS-UHFFFAOYSA-N', 'CI', 'Methyl iodide'),
    (19, 'REVIEW', 'IYKVLICPFCEZOF-UHFFFAOYSA-N', 'NC(N)=[Se]', 'Selenourea'),
    (20, 'EXCLUDE', 'JMANVNJQNLATNU-UHFFFAOYSA-N', 'N#CC#N', 'Cyanogen'),
]
draw_review_batch(batch)

# %%
batch = [
    (21, 'INCLUDE', 'JPOXNPPZZKNXOV-UHFFFAOYSA-N', 'ClCBr', 'Bromochloromethane'),
    (22, 'REVIEW', 'KTQYJQFGNYHXMB-UHFFFAOYSA-N', 'C[Si](Cl)Cl', 'Methyldichlorosilane'),
    (23, 'REVIEW', 'LSDPWZHWYPCBBB-UHFFFAOYSA-N', 'CS', 'Sodium methyl mercaptan'),
    (24, 'INCLUDE', 'LYGJENNIWJXYER-UHFFFAOYSA-N', 'C[N+](=O)[O-]', 'Nitromethane'),
]
draw_review_batch(batch)

# %%
batch = [
    (25, 'INCLUDE', 'MEUKEBNAABNAEX-UHFFFAOYSA-N', 'COO', 'Methyl hydroperoxide'),
    (26, 'INCLUDE', 'NEHMKBQYUWJMIP-UHFFFAOYSA-N', 'CCl', 'Methyl chloride / chloromethane'),
    (27, 'INCLUDE', 'NZZFYRREKKOMAT-UHFFFAOYSA-N', 'ICI', 'Diiodomethane'),
    (28, 'INCLUDE', 'OKJPEAGHQZHRQV-UHFFFAOYSA-N', 'IC(I)I', 'Iodoform'),
]
draw_review_batch(batch)

# %%
batch = [
    (29, 'INCLUDE', 'OKKJLVBELUTLKV-UHFFFAOYSA-N', 'CO', 'Methanol'),
    (30, 'REVIEW', 'OXBIRPQQKCQWGV-UHFFFAOYSA-N', 'C[As](O)O', 'Methylarsonous acid'),
    (31, 'EXCLUDE', 'QPJDMGCKMHUXFD-UHFFFAOYSA-N', 'N#CCl', 'Chlorine cyanide'),
    (32, 'INCLUDE', 'SQDFHQJTAWCFIB-UHFFFAOYSA-N', 'C=NO', 'Formaldoxime'),
]
draw_review_batch(batch)

# %%
batch = [
    (33, 'INCLUDE', 'UMGDCJDMYOKAJW-UHFFFAOYSA-N', 'NC(N)=S', 'Thiourea'),
    (34, 'INCLUDE', 'VOPWNXZWBYDODV-UHFFFAOYSA-N', 'FC(F)Cl', 'Chlorodifluoromethane'),
    (35, 'INCLUDE', 'WSFSSNUMVMOOMR-UHFFFAOYSA-N', 'C=O', 'Formaldehyde'),
    (36, 'INCLUDE', 'XSQUKJJJFZCRTK-UHFFFAOYSA-N', 'NC(N)=O', 'Urea'),
]
draw_review_batch(batch)

# %%
batch = [
    (37, 'INCLUDE', 'XWCDCDSDNJVCLO-UHFFFAOYSA-N', 'FCCl', 'Chlorofluoromethane'),
    (38, 'INCLUDE', 'XZBIXDPGRMLSTC-UHFFFAOYSA-N', 'NNC=O', 'Formylhydrazine'),
    (39, 'REVIEW', 'YAHQGPVDZBJVST-NSCUHMNNSA-N', '[H]/N=N/CO', 'Potassium (E/Z)-methanediazotate'),
    (40, 'REVIEW', 'YGYAWVDWMABLBF-UHFFFAOYSA-N', 'O=C(Cl)Cl', 'Phosgene'),
]
draw_review_batch(batch)

# %%
batch = [
    (41, 'INCLUDE', 'YMWUJEATGCHHMB-UHFFFAOYSA-N', 'ClCCl', 'Dichloromethane / methylene chloride'),
    (42, 'INCLUDE', 'YXHKONLOYHBTNS-UHFFFAOYSA-N', 'C=[N+]=[N-]', 'Diazomethane'),
    (43, 'INCLUDE', 'ZHNUHDYFZUAESO-UHFFFAOYSA-N', 'NC=O', 'Formamide'),
    (44, 'REVIEW', 'ZKGSUVMABCXPKK-UHFFFAOYSA-N', 'C[As](I)I', 'Diiodomethylarsine'),
]
draw_review_batch(batch)
